# %%
import pandas as pd 
import numpy as np
import re

# %%
hospital = pd.read_csv("서울시 병원 정보_전처리04.csv", encoding="cp949")
hospital
# Out:
#            기관ID                                         주소 병원분류명 응급실운영여부(T/F)  \
# 0      A1120837  서울특별시 금천구 벚꽃로 286, 삼성리더스타워 111~114호 (가산동)    의원            F
# 1      A1104130          서울특별시 강남구 도산대로 118 (논현동, 신사빌딩 2층)    의원            F
# 2      A1106364   서울특별시 강남구 테헤란로 509, 지하2층,지하1층일부,2층 (삼성동)    의원            F
# 3      A1106309   서울특별시 영등포구 경인로 841, 영등포우체국 4,5층 (영등포동4가)    의원            F
# 4      A1122178                서울특별시 강동구 올림픽로98길 11  (암사동)    의원            F
# ...         ...                                        ...   ...          ...
# 10076  A1100038     서울특별시 영등포구 버드나루로7길 12 (영등포동7가, 한강성심병원)  종합병원            T
# 10077  A1100053                 서울특별시 강동구 진황도로61길 53 (둔촌동)  종합병원            T
# 10078  A1100013                 서울특별시 성동구 왕십리로 222-1 (사근동)  종합병원            T
# 10079  A1100051                     서울특별시 광진구 자양로 85 (자양동)  종합병원            T
# 10080  A1100019            서울특별시 양천구 목동로 225, 홍익병원본관 (신정동)  종합병원            T
#
# ...

# %%
hospital['기관명'] = hospital['기관명'].str.upper()

# %%
hospital.to_csv('서울시 병원 정보.csv', encoding='cp949', index=False)
